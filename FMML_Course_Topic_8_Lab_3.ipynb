# %% [markdown]
# <a href="https://colab.research.google.com/github/Pujithagorre123/FMML_LAB-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-16 06:08:04--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   228MB/s    in 0.3s
#
# 2024-04-16 06:08:04 (228 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 19906   1303.5394v1  Influence diagram is a graphical representatio...    cs
# 3301   1501.04656v2  Determining the 3D structures of biological mo...  stat
# 6300   1611.01239v1  Low-variance gradient estimation is crucial fo...  stat
# 32365  1503.00600v1  We provide a simple and efficient algorithm fo...    cs
# 19306   1304.3105v1  Belief updating schemes in artificial intellig...    cs
# ...             ...                                                ...   ...
# 25703  1511.03296v2  We present the bilateral solver, a novel algor...    cs
# 29000  1708.02002v2  The highest accuracy object detectors to date ...    cs
# 6029   1606.03203v1  We study the problem of using causal models to...  stat
# 27772  1704.04671v1  We address the problem of temporal action loca...    cs
# 11160   1410.8864v1  We consider the problem of subspace clustering...  stat
#
#                                                    title  year  \
# 19906  Structural Controllability and Observability i...  2013
# 3301   Microscopic Advances with Large-Scale Learning...  2015
# 6300     Reparameterization trick for discrete variables  2016
# 32365  An $\mathcal{O}(n\log n)$ projection operator ...  2015
# 19306  The Rational and Computational Scope of Probab...  2013
# ...                                                  ...   ...
# 25703                          The Fast Bilateral Solver  2015
# 29000              Focal Loss for Dense Object Detection  2017
# 6029   Causal Bandits: Learning Good Interventions vi...  2016
# 27772  Temporal Action Localization by Structured Max...  2017
# 11160                         Greedy Subspace Clustering  2014
#
#                                                 keywords
# 19906  [influence, graphical, representation, uncerta...
# 3301   [determining, structures, biological, molecule...
# 6300   [estimation, graphical, parameterized, reparam...
# 32365  [efficient, algorithm, projection, regularizat...
# 19306  [artificial, intelligence, dimensional, langua...
# ...                                                  ...
# 25703  [bilateral, algorithm, smoothing, flexibility,...
# 29000  [detectors, popularized, classifier, candidate...
# 6029   [interventions, stochastic, environment, forma...
# 27772  [localization, localization, structured, predi...
# 11160  [clustering, dimensional, subspaces, subspaces...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 19906    [influence, graphical, representation, uncerta...
# 3301     [determining, structures, biological, molecule...
# 6300     [estimation, graphical, parameterized, reparam...
# 32365    [efficient, algorithm, projection, regularizat...
# 19306    [artificial, intelligence, dimensional, langua...
#                                ...
# 22685    [factorisation, decompose, multivariate, obser...
# 10306    [nonparametric, graphical, essentially, nonpar...
# 6093     [treatment, individual, information, recommend...
# 2768     [architectures, typically, cumbersome, automat...
# 22136    [introduces, importance, demonstrates, theoret...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8807 words.
# Out of those 4567 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e16f4d9c-606d-4203-ab4a-66f207167953" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e16f4d9c-606d-4203-ab4a-66f207167953")) {                    Plotly.newPlot(                        "e16f4d9c-606d-4203-ab4a-66f207167953",                        [{"x":["algorithms","variables","influence","structural","detecting","controllability","corresponds","numerical","challenging","knowledge","formulating","determined","inconsistency","observability","fundamental","intuitions","sometimes","representation","uncertainty","functional","reasoning","underlying","connection","insufficient","dependence","information","probabilistic","properties","developed","particular","graphical","formulated","structure","qualitative","initialization","optimization","estimation","reconstruct","determining","promising","application","recovering","structures","techniques","technique","represents","resulting","microscopic","discovery","computational","synthetic","biological","improvement","introduces","stochastic","molecules","reasonable","significantly","estimates","continuous","regarding","reparameterization","applicable","discontinuity","parameterized","theoretically","empirical","understood","guaranteed","operations","discontinuous","estimator","likelihood","inherently","marginalizing","variational","dependent","downloaded","algorithm","efficient","projection","implementation","regularization","constraint","elementary","conditional","limitations","languages","implications","certainty","combination","artificial","dimensional","independence","engineering","uncertain","interpretations","intelligence","semantics","relationship","presented","competing","concludes","assumptions","probabilities","cognitive","discussion","highlights","consisting","classifiers","demanding","accuracies","benchmark","identifies","demonstrated","discriminatively","unlabeled","recognition","discriminative","construct","significant","theoretical","invariant","specifically","similarly","adaptation","classification","unsupervised","hyperparameters","sentiment","approaches","theoretic","misclassification","validated","distributed","effectively","optimizing","representations","experimentally","different","instances","relationships","relational","hypergraph","clustering","typically","additionally","considered","outperform","vectorized","complexity","similarities","introduce","robustness","factorization","established","monocular","reconstruction","contributions","incremental","formulation","generates","integrates","recurrent","principles","published","distribution","framework","capability","backwards","components","continued","iterations","implementing","component","compatibility","implementations","development","flexibility","supporting","citations","undergoing","important","classifier","scientific","sensitive","reference","discourse","predictive","processing","analyzing","understanding","annotated","behavioral","reflecting","methodological","publication","influencing","centrality","demonstrate"],"y":[585,138,53,52,82,2,27,83,266,343,13,46,6,4,87,3,26,363,67,25,124,135,41,10,24,670,178,217,215,245,57,38,352,64,25,307,193,28,38,127,243,27,113,368,231,61,136,7,48,284,139,52,149,80,132,4,37,271,78,105,23,4,55,2,14,41,158,16,33,62,4,30,62,17,1,53,73,3,775,395,57,131,90,101,6,90,66,106,18,5,123,141,175,26,45,31,19,100,100,67,170,33,6,61,62,57,29,11,43,109,5,27,224,23,91,12,44,394,96,98,240,150,61,171,15,70,488,139,8,55,396,42,7,25,113,120,48,245,48,741,72,67,25,0,143,100,68,100,87,4,248,34,298,96,50,48,23,105,47,25,73,49,26,134,35,38,207,539,56,3,113,6,26,34,108,6,42,121,30,16,3,1,330,140,34,64,48,21,66,298,61,155,67,21,6,5,4,5,2,526],"type":"bar"},{"x":["algorithms","variables","influen ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4567,), (4567, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Binary</span> <span style=''>Particle</span> <span style=''>Swarm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>versus</span> <span style=''>Hybrid</span> <span style=''>Genetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inferring</span> <span style=''>Well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Supported</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>Phylogenetic</span> <span style=''>Trees</span> <br/><br/><span style=''>The</span> <span style=''>amount</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completely</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>sequenced</span> <span style=''>chloroplast</span> <span style=''>genomes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increases</span> <span style=''>rapidly</span> <span style=''>every</span> <span style=''>day</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5416666666666667);'>possibility</span> <span style=''>to</span> <span style=''>build</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>phylogenetic</span> <span style=''>trees</span> <span style=''>of</span> <span style=''>plant</span> <span style=''>species</span> <span style='background-color:rgba(0, 255, 0, 0.39130434782608703);'>Considering</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>close</span> <span style=''>plant</span> <span style=''>species</span> <span style=''>defined</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>according</span> <span style=''>to</span> <span style=''>their</span> <span style=''>chloroplasts</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>phylogenetic</span> <span style=''>tree</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>inferred</span> <span style=''>by</span> <span style=''>their</span> <span style=''>core</span> <span style=''>genes</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>necessarily</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supported</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>possible</span> <span style='background-color:rgba(0, 255, 0, 0.4054054054054055);'>occurrence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>problematic</span> <span style=''>genes</span> <span style=''>(ie</span> <span style=''>homoplasy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incomplete</span> <span style=''>lineage</span> <span style=''>sorting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>horizontal</span> <span style=''>gene</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transfers</span> <span style=''>etc)</span> <span style=''>which</span> <span style=''>may</span> <span style=''>blur</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>phylogenetic</span> <span style=''>signal</span> <span style=''>However</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>trustworthy</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>phylogenetic</span> <span style=''>tree</span> <span style=''>can</span> <span style=''>still</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>provided</span> <span style=''>such</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>blurring</span> <span style=''>genes</span> <span style=''>is</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Faithful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>Distance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representations</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reduction</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Classical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multidimensional</span> <span style=''>scaling</span> <span style=''>only</span> <span style=''>works</span> <span style=''>well</span> <span style=''>when</span> <span style=''>the</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>observed</span> <span style=''>in</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>space</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>faithfully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>in</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>space</span> <span style=''>Advanced</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Maximum</span> <span style=''>Variance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfolding</span> <span style=''>(MVU)</span> <span style=''>and</span> <span style=''>Minimum</span> <span style=''>Volume</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Embedding</span> <span style=''>(MVE)</span> <span style=''>use</span> <span style=''>Semi</span> <span style=''>Definite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Programming</span> <span style=''>(SDP)</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruct</span> <span style=''>such</span> <span style=''>faithful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>While</span> <span style=''>those</span> <span style=''>SDP</span> <span style=''>models</span> <span style=''>are</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>producing</span> <span style=''>high</span> <span style=''>quality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>configuration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerically</span> <span style=''>they</span> <span style=''>suffer</span> <span style=''>two</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>drawbacks</span> <span style=''>One</span> <span style=''>is</span> <span style=''>that</span> <span style=''>there</span> <span style=''>exist</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>configuration</span> <span style=''>The</span> <span style=''>other</span> <span style=''>is</span> <span style=''>that</span> <span style=''>they</span> <span style=''>are</span> <span style=''>slow</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Differential</span> <span style=''>Privacy</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>how</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4);'>communicate</span> <span style=''>findings</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>to</span> <span style=''>third</span> <span style=''>parties</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserving</span> <span style=''>the</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style=''>privacy</span> <span style=''>Our</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contributions</span> <span style=''>are</span> <span style=''>four</span> <span style='background-color:rgba(0, 255, 0, 0.33034111310592457);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>private</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>on</span> <span style=''>proba</span> <span style=''>bilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>These</span> <span style=''>include</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.42424242424242425);'>mechanisms</span> <span style=''>for</span> <span style=''>adding</span> <span style=''>noise</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>updates</span> <span style=''>either</span> <span style=''>directly</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6244131455399061);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>or</span> <span style=''>to</span> <span style=''>their</span> <span style=''>Fourier</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transform</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>preserve</span> <span style=''>update</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>We</span> <span style=''>also</span> <span style=''>utilise</span> <span style=''>a</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style='background-color:rgba(255, 0, 0, 0.6244131455399061);'>posterior</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3125);'>mechanism</span> <span style=''>for</span> <span style=''>which</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>specific</span> <span style=''>but</span> <span style=''>general</span> <span style=''>case</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>maximum</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.37931034482758624);'>posteriori</span> <span style=''>private</span> <span style='background-color:rgba(0, 255, 0, 0.3125);'>mechanism</span> <span style=''>Our</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>PIP</span> <span style=''>Distance</span> <span style=''>A</span> <span style=''>Unitary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>Metric</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Understanding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functionality</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensionality</span> <span style=''>of</span> <span style=''>Vector</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Embeddings</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>vector</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style=''>building</span> <span style=''>block</span> <span style=''>of</span> <span style=''>many</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>in</span> <span style=''>NLP</span> <span style=''>We</span> <span style=''>discover</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>unitary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariance</span> <span style=''>in</span> <span style=''>vector</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>which</span> <span style=''>is</span> <span style=''>required</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>This</span> <span style=''>unitary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariance</span> <span style=''>states</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essentially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>if</span> <span style=''>one</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>from</span> <span style=''>the</span> <span style=''>other</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style=''>a</span> <span style=''>relative</span> <span style=''>geometry</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preserving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style=''>for</span> <span style=''>example</span> <span style=''>a</span> <span style=''>rotation</span> <span style=''>This</span> <span style=''>idea</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Pairwise</span> <span style=''>Inner</span> <span style=''>Product</span> <span style=''>(PIP)</span> <span style=''>loss</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>unitary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>metric</span> <span style=''>for</span> <span style=''>the</span> <span style=''>distance</span> <span style=''>between</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>We</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12320402298850575)
# 	architecture (0.07974137931034483)
# 	segmentation (0.06716954022988506)
# 	processing (0.10704022988505747)
# 	representation (0.13038793103448276)
# 	information (0.2406609195402299)
# 	detection (0.12428160919540229)
# 	different (0.2661637931034483)
# 	convolutional (0.1257183908045977)
# 	recognition (0.14152298850574713)
#
# Some Statistics words are:
# 	distributions (0.11557539682539683)
# 	variables (0.13392857142857142)
# 	theoretical (0.14186507936507936)
# 	estimation (0.16319444444444445)
# 	statistical (0.15178571428571427)
# 	distribution (0.17807539682539683)
# 	algorithm (0.39037698412698413)
# 	inference (0.19791666666666666)
# 	dimensional (0.18601190476190477)
# 	regression (0.18253968253968253)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d779e6af-9629-43fe-8553-d7ef0cd8a84e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d779e6af-9629-43fe-8553-d7ef0cd8a84e")) {                    Plotly.newPlot(                        "d779e6af-9629-43fe-8553-d7ef0cd8a84e",                        [{"x":["algorithms","variables","influence","structural","detecting","controllability","corresponds","numerical","challenging","knowledge","formulating","determined","inconsistency","observability","fundamental","intuitions","sometimes","representation","uncertainty","functional","reasoning","underlying","connection","insufficient","dependence","information","probabilistic","properties","developed","particular","graphical","formulated","structure","qualitative","initialization","optimization","estimation","reconstruct","determining","promising","application","recovering","structures","techniques","technique","represents","resulting","microscopic","discovery","computational","synthetic","biological","improvement","introduces","stochastic","molecules","reasonable","significantly","estimates","continuous","regarding","reparameterization","applicable","discontinuity","parameterized","theoretically","empirical","understood","guaranteed","operations","discontinuous","estimator","likelihood","inherently","marginalizing","variational","dependent","downloaded","algorithm","efficient","projection","implementation","regularization","constraint","elementary","conditional","limitations","languages","implications","certainty","combination","artificial","dimensional","independence","engineering","uncertain","interpretations","intelligence","semantics","relationship","presented","competing","concludes","assumptions","probabilities","cognitive","discussion","highlights","consisting","classifiers","demanding","accuracies","benchmark","identifies","demonstrated","discriminatively","unlabeled","recognition","discriminative","construct","significant","theoretical","invariant","specifically","similarly","adaptation","classification","unsupervised","hyperparameters","sentiment","approaches","theoretic","misclassification","validated","distributed","effectively","optimizing","representations","experimentally","different","instances","relationships","relational","hypergraph","clustering","typically","additionally","considered","outperform","vectorized","complexity","similarities","introduce","robustness","factorization","established","monocular","reconstruction","contributions","incremental","formulation","generates","integrates","recurrent","principles","published","distribution","framework","capability","backwards","components","continued","iterations","implementing","component","compatibility","implementations","development","flexibility","supporting","citations","undergoing","important","classifier","scientific","sensitive","reference","discourse","predictive","processing","analyzing","understanding","annotated","behavioral","reflecting","methodological","publication","influencing","centrality","demonstrate","indicator","consensus","experiments","statistical","implement","simultaneously","causality","extensive","identifying","potential","therefore","prevention","inferring","practical","differential","inference","applications","guarantees","algorithmic","autonomous","automated","subsequently","prediction","minimization","assumption","screening","establish","simulations","consistency","conditions","equivalence","comparable","regularity","performance","addresses","corresponding","descriptive","especially","proximity","randomized","population","approximations","preserving","probability","sufficiently","producing","sketching","compelling","proportional","motivated","independently","artifacts","enhanc ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	hypergraph
# 	abnormality
# 	misspecified
# 	hospitals
# 	confronted
# 	semiparametric
# 	degenerate
# 	bivariate
# 	resurgence
# 	neuroimaging
# 	expecting
# 	integrable
# 	representer
# 	nonparanormal
# 	projectorg
# 	streamlined
# 	movielens
# 	straggler
# 	straggling
# 	stragglers
# Some words which never appear in Statistics papers:
# 	controllability
# 	certainty
# 	monocular
# 	backwards
# 	continued
# 	citations
# 	discourse
# 	descriptive
# 	compensates
# 	compensation
# 	entailing
# 	researches
# 	assimilate
# 	retrieves
# 	accordance
# 	footprints
# 	illumination
# 	appreciated
# 	detections
# 	compliance

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0857530780386954e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7741666666666667
